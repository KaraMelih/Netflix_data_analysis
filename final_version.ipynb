# %% [markdown]
# # Final collection of previous analysis

# %% [markdown]
# Directly import the dataframes and the functions and apply

# %%
from nfx_analysis import df, movies, tvseries
from nfx_analysis.funcs import get_lengths, find_actors_movies, chart_it
import matplotlib.pyplot as plt

# %%
chart_it(movies)

# %%
JA_mov = find_actors_movies(movies, 'Jennifer Aniston')
JA_ser = find_actors_movies(tvseries, 'Jennifer Aniston')

# %%
JA_mov
# Out:
#        show_id   type              title        director  \
# 827   70128696  Movie  The Bounty Hunter    Andy Tennant
# 2662  80242619  Movie     Murder Mystery  Kyle Newacheck
# 2948  70042688  Movie       The Break-Up     Peyton Reed
# 4120  80201490  Movie           Dumplin'   Anne Fletcher
# 5076  70039168  Movie       Rumor Has It      Rob Reiner
#
#                                                    cast  \
# 827   Jennifer Aniston, Gerard Butler, Jason Sudeiki...
# 2662  Adam Sandler, Jennifer Aniston, Luke Evans, Ge...
# 2948  Vince Vaughn, Jennifer Aniston, Joey Lauren Ad...
# 4120  Danielle Macdonald, Jennifer Aniston, Odeya Ru...
# 5076  Jennifer Aniston, Kevin Costner, Shirley MacLa...
#
#                                 country        date_added  release_year  \
# 827                       United States   October 1, 2019          2010
# 2662                      United States     June 14, 2019          2019
# ...

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(10,10))
plt.subplots_adjust(wspace=0.9)
chart_it(JA_mov, threshold=0, ax=ax1)
chart_it(JA_ser, threshold=0, ax=ax2)
